# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from math import pi
import seaborn as sns

data = pd.read_csv('C:/Users/NurulFatimah/Downloads/MateriDTS/ramenfix.csv')
print(data)
# Out:
#       Review #             Brand  \
# 0         2580         New Touch
# 1         2579          Just Way
# 2         2578            Nissin
# 3         2577           Wei Lih
# 4         2576    Ching's Secret
# 5         2575     Samyang Foods
# 6         2574           Acecook
# 7         2573       Ikeda Shoku
# 8         2572        Ripe'n'Dry
# 9         2571              KOKA
# 10        2570       Tao Kae Noi
# 11        2569          Yamachan
# 12        2568          Nongshim
# 13        2567            Nissin
# 14        2566            Nissin
# 15        2565              KOKA
# 16        2564              TRDP
# 17        2563          Yamachan
# 18        2562          Binh Tay
# 19        2561             Paldo
# 20        2560            Nissin
# 21        2559  Jackpot Teriyaki
# 22        2558              KOKA
# 23        2557          Yamachan
# 24        2556    Ching's Secret
# 25        2555     Samyang Foods
# 26        2554           Yum-Mie
# 27        2553            Nissin
# 28        2552           MyKuali
# 29        2551              KOKA
# ...        ...               ...
# 2550        30             Myojo
# 2551        29          Mee Jang
# 2552        28            Nissin
# 2553        27            Nissin
# 2554        26            Nissin
# 2555        25            Nissin
# 2556        24            Nissin
# 2557        23            Nissin
# 2558        22          Nongshim
# 2559        21          Nongshim
# 2560        20          Nongshim
# 2561        19          Nongshim
# 2562        18            Ottogi
# 2563        17         Quickchow
# 2564        16           Samyang
# 2565        15           Samyang
# 2566        14           Samyang
# 2567        13   Sapporo Ichiban
# 2568        12   Sapporo Ichiban
# 2569        11       Six Fortune
# 2570        10             Smack
# 2571         9             Sutah
# 2572         8            Tung-I
# 2573         7           Ve Wong
# 2574         6             Vifon
# 2575         5             Vifon
# 2576         4           Wai Wai
# 2577         3           Wai Wai
# 2578         2           Wai Wai
# 2579         1          Westbrae
#
#                                                 Variety Style      Country  \
# 0                             T's Restaurant Tantanmen    Cup        Japan
# 1     Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack       Taiwan
# 2                         Cup Noodles Chicken Vegetable   Cup          USA
# 3                         GGE Ramen Snack Tomato Flavor  Pack       Taiwan
# 4                                       Singapore Curry  Pack        India
# 5                                Kimchi song Song Ramen  Pack  South Korea
# 6                   Spice Deli Tantan Men With Cilantro   Cup        Japan
# 7                                 Nabeyaki Kitsune Udon  Tray        Japan
# 8                              Hokkaido Soy Sauce Ramen  Pack        Japan
# 9                 The Original Spicy Stir-Fried Noodles  Pack    Singapore
# 10                          Creamy tom Yum Kung Flavour  Pack     Thailand
# 11                              Yokohama Tonkotsu Shoyu  Pack          USA
# 12                   Mr. Bibim Stir-Fried Kimchi Flavor  Pack  South Korea
# 13                         Deka Buto Kimchi Pork Flavor  Bowl        Japan
# 14    Demae Ramen Bar Noodle Aka Tonkotsu Flavour In...  Pack    Hong Kong
# 15                     Mushroom Flavour Instant Noodles   Cup    Singapore
# 16                                 Mario Masala Noodles  Pack        India
# 17                                    Tokyo Shoyu Ramen  Pack          USA
# 18                                           Mi Hai Cua  Pack      Vietnam
# 19                                      Premium Gomtang  Pack  South Korea
# 28       5      NaN
# 29       4      NaN
# ...    ...      ...
# 2550     1      NaN
# 2551   3.5      NaN
# 2552     5      NaN
# 2553     4      NaN
# 2554     4      NaN
# 2555     3      NaN
# 2556     2      NaN
# 2557   4.5      NaN
# 2558  3.75      NaN
# 2559     4      NaN
# 2560   3.5      NaN
# 2561     4      NaN
# 2562   3.5      NaN
# 2563   2.5      NaN
# 2564   3.5      NaN
# 2565   2.5      NaN
# 2566   3.5      NaN
# 2567     5  2012 #4
# 2568   2.5      NaN
# 2569     2      NaN
# 2570   1.5      NaN
# 2571     2      NaN
# 2572     3      NaN
# 2573     1      NaN
# 2574   2.5      NaN
# 2575   3.5      NaN
# 2576     1      NaN
# 2577     2      NaN
# 2578     2      NaN
# 2579   0.5      NaN
#
# [2580 rows x 7 columns]

# %%
import pandas as pd
file="C:/Users/NurulFatimah/Downloads/MateriDTS/ramenfix.csv"
data=pd.read_csv(file, delimiter = ',',sep='|', encoding='latin-1')

# %%
#data[3:6]
data.head(500)
# Out:
#      Review #             Brand  \
# 0        2580         New Touch
# 1        2579          Just Way
# 2        2578            Nissin
# 3        2577           Wei Lih
# 4        2576    Ching's Secret
# 5        2575     Samyang Foods
# 6        2574           Acecook
# 7        2573       Ikeda Shoku
# 8        2572        Ripe'n'Dry
# 9        2571              KOKA
# 10       2570       Tao Kae Noi
# 11       2569          Yamachan
# 12       2568          Nongshim
# 13       2567            Nissin
# 14       2566            Nissin
# 15       2565              KOKA
# 16       2564              TRDP
# 17       2563          Yamachan
# 18       2562          Binh Tay
# 19       2561             Paldo
# 20       2560            Nissin
# 21       2559  Jackpot Teriyaki
# 22       2558              KOKA
# 23       2557          Yamachan
# 24       2556    Ching's Secret
# 25       2555     Samyang Foods
# 26       2554           Yum-Mie
# 27       2553            Nissin
# 28       2552           MyKuali
# 29       2551              KOKA
# ..        ...               ...
# 470      2110       Great Value
# 471      2109       Oni Hot Pot
# 472      2108           Weh Lih
# 473      2107            Nissin
# 474      2106            Itomen
# 475      2105          Maruchan
# 476      2104              Wang
# 477      2103            Roland
# 478      2102            Nissin
# 479      2101     Samyang Foods
# 480      2100             Myojo
# 481      2099             Sanpo
# 482      2098          Nongshim
# 483      2097            CarJEN
# 484      2096          Maruchan
# 485      2095            Nissin
# 486      2094          Nongshim
# 487      2093       Oni Hot Pot
# 488      2092              Doll
# 489      2091           MyKuali
# 490      2090            Nissin
# 491      2089            Nissin
# 492      2088            Nissin
# 493      2087            Nissin
# 494      2086            Nissin
# 495      2085              Fuku
# 496      2084            Nissin
# 497      2083            Nissin
# 498      2082            Nissin
# 499      2081            Nissin
#
#                                                Variety Style      Country  \
# 0                            T's Restaurant Tantanmen    Cup        Japan
# 1    Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack       Taiwan
# 2                        Cup Noodles Chicken Vegetable   Cup          USA
# 3                        GGE Ramen Snack Tomato Flavor  Pack       Taiwan
# 4                                      Singapore Curry  Pack        India
# 5                               Kimchi song Song Ramen  Pack  South Korea
# 493  Mie Goreng Indonesia Stir Noodle Original Flavour  Pack    Hong Kong
# 494         Demae Ramen Sesame Flavour Instant Noodles  Pack    Hong Kong
# 495              Superior Soup Instant Rice Vermicelli  Bowl    Hong Kong
# 496  Demae Ramen Straight Noodle Kyushu Tonkotsu In...  Pack    Hong Kong
# 497  Taisho Fried Noodle Sesame Paste Flavour Insta...  Pack    Hong Kong
# 498                   Cup Noodles Pork Chowder Flavour   Cup    Hong Kong
# 499                       Cup Mifun Spicy Beef Flavour   Cup    Hong Kong
#
#     Stars Top Ten
# 0    3.75     NaN
# 1       1     NaN
# 2    2.25     NaN
# 3    2.75     NaN
# 4    3.75     NaN
# 5    4.75     NaN
# 6       4     NaN
# 7    3.75     NaN
# 8    0.25     NaN
# 9     2.5     NaN
# 10      5     NaN
# 11      5     NaN
# 12   4.25     NaN
# 13    4.5     NaN
# 14      5     NaN
# 15    3.5     NaN
# 16   3.75     NaN
# 17      5     NaN
# 18      4     NaN
# 19      4     NaN
# 20   4.25     NaN
# 21      5     NaN
# 22      5     NaN
# 23   4.75     NaN
# 24   4.25     NaN
# 25   4.25     NaN
# 26    3.5     NaN
# 27   4.75     NaN
# 28      5     NaN
# 29      4     NaN
# ..    ...     ...
# 470  3.00     NaN
# 471   4.3     NaN
# 472     1     NaN
# 473   4.5     NaN
# 474   3.5     NaN
# 475     3     NaN
# 476     4     NaN
# 477     0     NaN
# 478     5     NaN
# 479     4     NaN
# 480     4     NaN
# 481     4     NaN
# 482     5     NaN
# 483     5     NaN
# 484     4     NaN
# 485     5     NaN
# 486     5     NaN
# 487     2     NaN
# 488     4     NaN
# 489     5     NaN
# 490     5     NaN
# 491     5     NaN
# 492     4     NaN
# 493     4     NaN
# 494     5     NaN
# 495     5     NaN
# 496     5     NaN
# 497     5     NaN
# 498     4     NaN
# 499     4     NaN
#
# [500 rows x 7 columns]

# %%
print(data['Brand'].value_counts())
# Out:
# Nissin                             381
# Nongshim                            98
# Maruchan                            76
# Mama                                71
# Paldo                               66
# Myojo                               63
# Indomie                             53
# Samyang Foods                       52
# Ottogi                              46
# Vina Acecook                        34
# Lucky Me!                           34
# Vifon                               33
# Maggi                               30
# Mamee                               29
# Master Kong                         28
# MAMA                                27
# A-Sha Dry Noodle                    26
# Sapporo Ichiban                     25
# Wai Wai                             25
# KOKA                                25
# MyKuali                             24
# Ve Wong                             24
# JML                                 23
# Samyang                             19
# Koka                                18
# Batchelors                          16
# Doll                                16
# Kamfen                              15
# Wei Lih                             15
# Mr. Noodles                         15
#                                   ...
# Fu Chang Chinese Noodle Company      1
# Mexi-Ramen                           1
# GGE                                  1
# Zow Zow                              1
# Golden Wonder                        1
# Daraz                                1
# Chorip Dong                          1
# Sokensha                             1
# Sakurai                              1
# Samurai Ramen                        1
# One Dish Asia                        1
# Mitoku                               1
# The Bridge                           1
# Yamadai                              1
# Rocket Brand                         1
# La Moderna                           1
# Thien Houng Foods                    1
# Sutah                                1
# Peyang                               1
# Thailand         191
# China            169
# Malaysia         156
# Hong Kong        137
# Indonesia        126
# Singapore        109
# Vietnam          108
# UK                69
# Philippines       47
# Canada            41
# India             31
# Germany           27
# Mexico            25
# Australia         22
# Netherlands       15
# Nepal             14
# Myanmar           14
# Pakistan           9
# Hungary            9
# Bangladesh         7
# Colombia           6
# Brazil             5
# Cambodia           5
# Poland             4
# Fiji               4
# Holland            4
# Dubai              3
# Finland            3
# Sarawak            3
# Sweden             3
# Estonia            2
# Ghana              2
# United States      1
# Nigeria            1
# Name: Country, dtype: int64

# %%
print(data['Stars'].value_counts())
# Out:
# 4          384
# 5          369
# 3.75       350
# 3.5        326
# 3          173
# 3.25       170
# 4.25       143
# 4.5        132
# 2.75        85
# 2           68
# 2.5         67
# 4.75        64
# 1.5         37
# 1.75        27
# 1           26
# 0           26
# 2.25        21
# 0.5         14
# 0.25        11
# 5.0         10
# 1.25        10
# 3.50         9
# 5.00         7
# 4.00         6
# 4.3          4
# Unrated      3
# 4.50         3
# 4.0          3
# 3.8          3
# 4.125        2
# 3.1          2
# 2.8          2
# 2.9          2
# 3.0          2
# 1.1          2
# 2.3          2
# 2.1          1
# 1.8          1
# 0.9          1
# 3.00         1
# 0.1          1
# 2.125        1
# 3.125        1
# 3.3          1
# 0.75         1
# 3.7          1
# 3.65         1
# 3.4          1
# 3.2          1
# 3.6          1
# 2.85         1
# Name: Stars, dtype: int64

# %%
print(data['Style'].value_counts())
# Out:
# Pack    1531
# Bowl     481
# Cup      450
# Tray     108
# Box        6
# Can        1
# Bar        1
# Name: Style, dtype: int64

# %%
print(data['Top Ten'].value_counts())
# Out:
# \n          4
# 2012 #10    1
# 2016 #9     1
# 2012 #2     1
# 2015 #10    1
# 2013 #1     1
# 2016 #8     1
# 2014 #5     1
# 2014 #7     1
# 2013 #4     1
# 2015 #7     1
# 2012 #6     1
# 2012 #7     1
# 2016 #10    1
# 2015 #8     1
# 2012 #9     1
# 2012 #4     1
# 2016 #7     1
# 2012 #3     1
# 2014 #1     1
# 2015 #9     1
# 2013 #9     1
# 2016 #1     1
# 2013 #10    1
# 2015 #4     1
# 2014 #10    1
# 2015 #6     1
# 2016 #5     1
# 2014 #6     1
# 2014 #9     1
# 2013 #3     1
# 2012 #5     1
# 2015 #1     1
# 2014 #4     1
# 2014 #8     1
# 2013 #6     1
# 2012 #1     1
# 2013 #2     1
# Name: Top Ten, dtype: int64

# %%
import matplotlib.pyplot as plt
from pywaffle import Waffle
data = {'Japan': 352, 'USA':323, 'South Korea':309, 'Taiwan':224, 'Thailand':191, 'China': 169, 'Malaysia':156, 'Hongkong':137,
       'Indonesia':126, 'Singapore':109, 'Vietnam':108, 'UK':69, 'Philippines':47, 'Canada':41, 'India':31, 'Germany':27, 'Mexico':25,
       'Australia':22, 'Netherlands':15, 'Nepal':14, 'Myanmar':14, 'Pakistan':9, 'Hungary':9, 'Bangladesh':7, 'Colombia':6, 'Brazil':5,
       'Cambodia':5, 'Poland':4, 'Fiji':4, 'Holland':4, 'Dubai':3, 'Finland':3, 'Sarawak':3, 'Sweden':3, 'Estonia':2, 'Ghana':2, 'United States':1, 'Nigeria':1}
fig = plt.figure(
    FigureClass=Waffle, 
    rows=25, 
    columns=25,
    values=data, 
    legend={'loc': 'upper left', 'bbox_to_anchor': (1.5, 1 )}
)
plt.title("Banyak Jenis Mie Ramen Berdasarkan Country \n")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\tight_layout.py:181: UserWarning:
#
# Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py:2369: UserWarning:
#
# This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
# <Waffle size 432x288 with 1 Axes>

# %%
import matplotlib.pyplot as plt

labels = ['Cup', 'Tray','Can', 'Pack','Bar', 'Bowl','Box']
sizes = [17.44, 4.18, 0.03, 59.34, 0.03, 18.64, 0.23]
explode = (0, 0, 0, 0, 0, 0, 0)
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.2f%%', shadow=True, startangle=500)
ax1.axis('equal') 

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

sns.countplot(np.round(data['Stars'].replace('Unrated', np.nan).dropna().astype(np.float64)))
plt.title("Banyak Data Berdasarkan Rating dari Mie Ramen \n")
# Out:
# Text(0.5, 1.0, 'Banyak Data Berdasarkan Rating dari Mie Ramen \n')

# %%
plt.figure(figsize=(7,7))
data.Style.value_counts().plot(kind='line')
plt.title('Jumlah Data Berdasarkan Style dari Mie Ramen')
plt.xlabel('Bentuk Kemasan Ramen')
plt.ylabel('Banyak Data')
plt.show()

# %%
import matplotlib.pyplot as plt
from pywaffle import Waffle

c = data['Country']
fig = plt.figure(
    FigureClass=Waffle, 
    rows=25, 
    columns=25,
    values=c, 
legend={'loc': 'upper left', 'bbox_to_anchor':(1.5, 1 )}
)
plt.title("Banyak Jenis Mie Ramen Berdasarkan Country \n")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-99-fb1fcb887f37> in <module>
#       8     columns=25,
#       9     values=c,
# ---> 10 legend={'loc': 'upper left', 'bbox_to_anchor':(1.5, 1 )}
#      11 )
#      12 plt.title("Banyak Jenis Mie Ramen Berdasarkan Country \n")
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     523                                         frameon=frameon,
#     524                                         FigureClass=FigureClass,
# --> 525                                         **kwargs)
#     526
#     527         if figLabel:
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in new_figure_manager(cls, num, *args, **kwargs)
#    3215         from matplotlib.figure import Figure
#    3216         fig_cls = kwargs.pop('FigureClass', Figure)
# -> 3217         fig = fig_cls(*args, **kwargs)
#    3218         return cls.new_figure_manager_given_figure(num, fig)
#    3219
#
# C:\ProgramData\Anaconda3\lib\site-packages\pywaffle\waffle.py in __init__(self, *args, **kwargs)
#     202
#     203         for loc, setting in self.plots.items():
# --> 204             self._waffle(loc, **copy.deepcopy(setting))
#     205
#     206         # Adjust the layout
#
# C:\ProgramData\Anaconda3\lib\site-packages\pywaffle\waffle.py in _waffle(self, loc, **kwargs)
#     254         self.ax.set_anchor(self._pa['plot_anchor'])
#     255
# --> 256         self.value_sum = float(sum(self._pa['values']))
#     257
#     258         # if column number is not given, use the values as number of blocks
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
